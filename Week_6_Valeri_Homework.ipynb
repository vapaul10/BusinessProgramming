# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/BusinessProgramming/blob/Week-6----Assignments/Week_6_Valeri_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6.2.3 Problem-Solving With Top-Down Design Question 1
# Week 6 · Design With Functions
# Item 3 of 5
#
# Draw a structure chart for one of the solutions to the programming projects of Lessons 4 and 5. The program should include at least two function definitions other than the main function.
# ![STRUTURE.png](data:image/png;base64,...)

# %% [markdown]
# #6.2.4  Question 2
#
# ```
# Describe the processes of top-down design and stepwise refinement. Where does the design start, and how does it proceed?
# ```

# %%
""" Top-Down starts with main function. And each function is def or defined. This function solves the program’s problem in an abstract way, by decomposing the problem into subproblems and calling other functions to solve these. Each of these functions in turn is designed in the same manner. Stepwise refinement is the process of filling in the details of each function definition. """
# Out:
# ' Top-Down starts with main function. And each function is def or defined. This function solves the program’s problem in an abstract way, by decomposing the problem into subproblems and calling other functions to solve these. Each of these functions in turn is designed in the same manner. Stepwise refinement is the process of filling in the details of each function definition. '
