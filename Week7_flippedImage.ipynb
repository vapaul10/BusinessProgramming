# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/BusinessProgramming/blob/Week-7-Assignments/Week7_flippedImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Week 7 Homework Flipped Image**

# %%
#str:url  = https://github.com/imageio/imageio-binaries/raw/master/images/chelsea.png

# %%
import imageio
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
url = "https://github.com/imageio/imageio-binaries/raw/master/images/chelsea.png"

img = imageio.imread(url)import numpy as np
img = mpimg.imread(url)
imgCat = np.flipud(img)
#img2 = np.flipud(img)
plt.imshow(imgCat)

plt.savefig("chelsea_fliped_vertically.png", dpi=200)
plt.show("chelsea_fliped_vertically.png")
print(url)
print('Type of the image : ' , type(img)) 
print('Shape of the image : {}'.format(img.shape)) 
print('Image Height {}'.format(img.shape[0])) 
print('Image Width {}'.format(img.shape[1])) 
print('Dimension of the Image {}'.format(img.ndim))
# Out:
# https://github.com/imageio/imageio-binaries/raw/master/images/chelsea.png
# Type of the image :  <class 'numpy.ndarray'>
# Shape of the image : (300, 451, 3)
# Image Height 300
# Image Width 451
# Dimension of the Image 3

# %%
print('Type of the image : ' , type(img)) 
print('Shape of the image : {}'.format(img.shape)) 
print('Image Height {}'.format(img.shape[0])) 
print('Image Width {}'.format(img.shape[1])) 
print('Dimension of the Image {}'.format(img.ndim))
plt.title('C channel') 
plt.ylabel('Height {}'.format(img.shape[0])) 
plt.xlabel('Width {}'.format(img.shape[1])) 
plt.imshow(img[ : , : , 0])
plt.show("chelsea_fliped_vertically.png")
# Out:
# Type of the image :  <class 'numpy.ndarray'>
# Shape of the image : (300, 451, 3)
# Image Height 300
# Image Width 451
# Dimension of the Image 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
url = "https://github.com/imageio/imageio-binaries/raw/master/images/chelsea.png"

img = imageio.imread(url)
img = mpimg.imread(url)

imga = np.flip(img,axis=None)
plt.imshow(imga)
#img3 = np.fliplr(img)
#plt.imshow(img3)
#np.flip(img2, axis=none)

plt.savefig("chelsea_flipped.png", dpi=200)
imga = plt.show("chelsea_flipped.png")
print(url)
# Out:
# https://github.com/imageio/imageio-binaries/raw/master/images/chelsea.png
