# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/BusinessProgramming/blob/Week-7-Assignments/Copy_of_ISTM_631_7th_session_10_12_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [1,2,3,4]

L2 = [2,3,4,5]

# %%
L2 = []

for i,n in enumerate(L):
  n += 1
  L2.append(n)

# %%
L2
# Out:
# [2, 3, 4, 5]

# %%
 import imageio
 import matplotlib.pyplot as plt
 # %matplotlib inline

# %%
url = 'https://thumbor.forbes.com/thumbor/700x345/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2Fb1f516bb9b6a0db652267d3e59f425a6%2F0x0.jpg%3Ffit%3Dscale%26background%3D000000'

url = "https://seaver.pepperdine.edu/about/images/virtual-experience.jpg"

pic = imageio.imread(url)
plt.figure(figsize = (10,10))
plt.imshow(pic)

# %% [markdown]
# R --> 0-255
#
# G --> 0-255
#
# B --> 0-255

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Height {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of the Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (415, 886, 3)
# Image Height 415
# Image Width 886
# Dimension of the Image 3

# %%
print('Image size {}'.format(pic.size)) 
print('Maximum RGB value in this image {}'.format(pic.max())) 
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 1103070
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
# A specific pixel located at Row : 100 ; Column : 50  
# Each channel's value of it, gradually R , G , B  
print('Value of only R channel {}'.format(pic[ 100, 50, 0])) 
print('Value of only G channel {}'.format(pic[ 100, 50, 1])) 
print('Value of only B channel {}'.format(pic[ 100, 50, 2]))
# Out:
# Value of only R channel 34
# Value of only G channel 48
# Value of only B channel 48

# %%
plt.title('R channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 1]) 
plt.show()

# %%
plt.title('B channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 2]) 
plt.show()

# %%
pic[0:70 , : , 0] = 255 # full intensity to those pixel's R channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
pic[0:70 , : , 0] = 255 # full intensity to those pixel's R channel 
pic[0:70 , : , 1] = 0
pic[0:70 , : , 2] = 0
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
pic[100:170 , : , 1] = 255 # full intensity to those pixel's G channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
pic[200:270 , : , 2] = 255 # full intensity to those pixel's B channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
# set value 200 of all channels to those pixels which turns them to gray 
pic[ 50:150 , 400:500 , [0,1,2] ] = 200  
plt.figure( figsize = (15,15)) 
plt.imshow(pic) 
plt.show()

# %% [markdown]
# (0,0) -- (415, 886)
#
# (0,1) -- (415, 885)
#
# (0,2) -- (415, 884 )

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Height {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of the Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (415, 886, 3)
# Image Height 415
# Image Width 886
# Dimension of the Image 3

# %% [markdown]
# 415*866
#
# n*n
#
# O(n^2)
#
# O(1)

# %%
for i in range(pic.shape[0]-1):
  for j in range(pic.shape[1]-1):
    dummy0 = pic[ i , j , 0 ] 
    dummy1 = pic[ i , j , 1 ] 
    dummy2 = pic[ i , j , 2 ]

    pic[ i , j , 0 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 0 ]
    pic[ i , j , 1 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 1 ]
    pic[ i , j , 2 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 2 ]

    pic[ pic.shape[0] - i , pic.shape[1]- j , 0 ] = dummy0
    pic[ pic.shape[0] - i , pic.shape[1]- j , 1 ] = dummy1
    pic[ pic.shape[0] - i , pic.shape[1]- j , 2 ] = dummy2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-f5ced23d8b03> in <module>()
#       5     dummy2 = pic[ i , j , 2 ]
#       6
# ----> 7     pic[ i , j , 0 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 0 ]
#       8     pic[ i , j , 1 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 1 ]
#       9     pic[ i , j , 2 ] = pic[ pic.shape[0] - i , pic.shape[1]- j , 2 ]
#
# IndexError: index 1000 is out of bounds for axis 0 with size 1000

# %%
pic[ i , j , [0,1,2]  ], pic[ pic.shape[0]- i , pic.shape[1] - j , [0,1,2]  ] = pic[ pic.shape[0]- i , pic.shape[1] - j , [0,1,2]  ], pic[ i , j , [0,1,2]  ]

# %%
import numpy as np 
pic = imageio.imread(url) 
fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5))  
for c, ax in zip(range(3), ax):     
     # create zero matrix        
     split_img = np.zeros(pic.shape, dtype="uint8") 
     # 'dtype' by default: 'numpy.float64'  # assing each channel      
     split_img[ :, :, c] = pic[ :, :, c] # display each channel     
     ax.imshow(split_img)

# %%
pic = imageio.imread(url) 
gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114])   
gray = gray(pic) 
plt.figure( figsize = (5,5))  
plt.imshow(gray, cmap = plt.get_cmap(name = 'gray')) 
plt.show()

# %%
url = 'https://thumbor.forbes.com/thumbor/700x345/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2Fb1f516bb9b6a0db652267d3e59f425a6%2F0x0.jpg%3Ffit%3Dscale%26background%3D000000'


 
pic = imageio.imread(url)
plt.figure(figsize = (10,10))
plt.imshow(pic)

# %% [markdown]
# edge detectioin

# %%
import numpy as np

#define the vertical filter
vertical_filter = [[-1,-2,-1], [0,0,0], [1,2,1]]

#define the horizontal filter
horizontal_filter = [[-1,0,1], [-2,0,2], [-1,0,1]]

#read in the pinwheel image
#img = plt.imread(url)
img = pic
#get the dimensions of the image
n,m,d = img.shape

#initialize the edges image
edges_img = img.copy()

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

#define the vertical filter
vertical_filter = [[-1,-2,-1], [0,0,0], [1,2,1]]

#define the horizontal filter
horizontal_filter = [[-1,0,1], [-2,0,2], [-1,0,1]]

#read in the pinwheel image
img = pic 

#get the dimensions of the image
n,m,d = img.shape

#initialize the edges image
edges_img = img.copy()

#loop over all pixels in the image
for row in range(3, n-2):
    for col in range(3, m-2):
        
        #create little local 3x3 box
        local_pixels = img[row-1:row+2, col-1:col+2, 0]
        
        #apply the vertical filter
        vertical_transformed_pixels = vertical_filter*local_pixels
        #remap the vertical score
        vertical_score = vertical_transformed_pixels.sum()/4
        
        #apply the horizontal filter
        horizontal_transformed_pixels = horizontal_filter*local_pixels
        #remap the horizontal score
        horizontal_score = horizontal_transformed_pixels.sum()/4
        
        #combine the horizontal and vertical scores into a total edge score
        edge_score = (vertical_score**2 + horizontal_score**2)**.5
        
        #insert this edge score into the edges image
        edges_img[row, col] = [edge_score]*3

#remap the values in the 0-1 range in case they went out of bounds
edges_img = edges_img/edges_img.max()

# %%
plt.imshow(edges_img)

# %%
picCopy = pic

# %%
import cv2
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 6 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (4,635 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.6-py2.py3-none-any.whl size=13629 sha256=2af22566b23df9de88d540b0962b4d2e3e5e1fee1d862a8c0bb0121f64a6c2bb
#   Stored in directory: /root/.cache/pip/wheels/ee/71/72/b98430261d849ae631e283dfc7ccb456a3fb2ed2205714b63f
# Successfully built pytesseract
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
url3 = 'https://ih0.redbubble.net/image.359995156.6854/fposter,small,wall_texture,product,750x1000.u2.jpg'

pic = imageio.imread(url3)
plt.figure(figsize = (10,10))
plt.imshow(pic)

# %%
text = pytesseract.image_to_string(pic)
print(text)
# Out:
# Tee
#
# Tragicall Hiftorie of
# HAMLET
#
# Prince of Denmarkes
#
# By William Shake-{peare.
#
# Asit hath beene dinerfe times aétedby his Highnefftfer-
# wants in the Cittie of London : asal{o inthe nwo V-
# niuerfities of Cambridgeand Oxford,and efe-where
#
#
#
# AtLondon printed for N.L- and John Trundell.
# 1603.
